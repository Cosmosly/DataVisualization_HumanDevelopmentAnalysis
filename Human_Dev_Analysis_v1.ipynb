# %% [markdown]
# # Human Devlopment Analysis
# - author: Yao

# %% [markdown]
# ### Step 1: Import the relevant packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2: Import 6 data sets(.csv) and have a general look

# %%
# import 6 .csv file
pd_gender_dev = pd.read_csv('gender_development.csv')
pd_human_dev = pd.read_csv('human_development.csv')
pd_gender_inequality = pd.read_csv('gender_inequality.csv')
pd_inequality_adjusted = pd.read_csv('inequality_adjusted.csv')
pd_nD_poverty = pd.read_csv('multidimensional_poverty.csv')
pd_historical_index = pd.read_csv('historical_index.csv')

# %%
# Have a look at the shpe of each file
pd_gender_dev.shape, pd_human_dev.shape ,pd_gender_inequality.shape, pd_inequality_adjusted.shape, pd_nD_poverty.shape, pd_historical_index.shape
# Out:
# ((195, 13), (195, 8), (195, 10), (195, 16), (101, 13), (195, 9))

# %%
# Look at the head of each file, to see their columns and values.
pd_gender_dev.head()
# Out:
#    GDI Rank      Country Gender Development Index (GDI)  \
# 0       1.0       Norway                          0.996
# 1       2.0    Australia                          0.976
# 2       3.0  Switzerland                           0.95
# 3       4.0      Denmark                          0.977
# 4       5.0  Netherlands                          0.947
#
#   Human Development Index (Female) Human Development Index (Male)  \
# 0                             0.94                          0.944
# 1                            0.922                          0.945
# 2                            0.898                          0.945
# 3                            0.912                          0.934
# 4                            0.893                          0.943
#
#   Life Expectancy at Birth (Female) Life Expectancy at Birth (Male)  \
# 0                              83.6                            79.5
# 1                              84.5                            80.3
# ...

# %%
pd_gender_dev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 13 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   GDI Rank                                             188 non-null    float64
#  1   Country                                              195 non-null    object
#  2   Gender Development Index (GDI)                       195 non-null    object
#  3   Human Development Index (Female)                     195 non-null    object
#  4   Human Development Index (Male)                       195 non-null    object
#  5   Life Expectancy at Birth (Female)                    195 non-null    object
#  6   Life Expectancy at Birth (Male)                      195 non-null    object
#  7   Expected Years of Education (Female)                 195 non-null    object
# ...

# %%
pd_human_dev.head()
# Out:
#    HDI Rank      Country  Human Development Index (HDI)  \
# 0       1.0       Norway                          0.944
# 1       2.0    Australia                          0.935
# 2       3.0  Switzerland                          0.930
# 3       4.0      Denmark                          0.923
# 4       5.0  Netherlands                          0.922
#
#    Life Expectancy at Birth  Expected Years of Education  \
# 0                      81.6                         17.5
# 1                      82.4                         20.2
# 2                      83.0                         15.8
# 3                      80.2                         18.7
# 4                      81.6                         17.9
#
#    Mean Years of Education Gross National Income (GNI) per Capita  \
# 0                     12.6                                 64,992
# 1                     13.0                                 42,261
# 2                     12.8                                 56,431
# ...

# %%
pd_human_dev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   HDI Rank                                188 non-null    float64
#  1   Country                                 195 non-null    object
#  2   Human Development Index (HDI)           195 non-null    float64
#  3   Life Expectancy at Birth                195 non-null    float64
#  4   Expected Years of Education             195 non-null    float64
#  5   Mean Years of Education                 195 non-null    float64
#  6   Gross National Income (GNI) per Capita  195 non-null    object
#  7   GNI per Capita Rank Minus HDI Rank      188 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 12.3+ KB

# %%
pd_gender_inequality.head()
# Out:
#    GII Rank      Country Gender Inequality Index (GII)  \
# 0       1.0       Norway                         0.067
# 1       2.0    Australia                          0.11
# 2       3.0  Switzerland                         0.028
# 3       4.0      Denmark                         0.048
# 4       5.0  Netherlands                         0.062
#
#   Maternal Mortality Ratio Adolescent Birth Rate  \
# 0                        4                   7.8
# 1                        6                  12.1
# 2                        6                   1.9
# 3                        5                   5.1
# 4                        6                   6.2
#
#   Percent Representation in Parliament  \
# 0                                 39.6
# 1                                 30.5
# 2                                 28.5
# 3                                   38
# 4                                 36.9
#
#   Population with Secondary Education (Female)  \
# ...

# %%
pd_gender_inequality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 10 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   GII Rank                                      188 non-null    float64
#  1   Country                                       195 non-null    object
#  2   Gender Inequality Index (GII)                 195 non-null    object
#  3   Maternal Mortality Ratio                      195 non-null    object
#  4   Adolescent Birth Rate                         195 non-null    object
#  5   Percent Representation in Parliament          195 non-null    object
#  6   Population with Secondary Education (Female)  195 non-null    object
#  7   Population with Secondary Education (Male)    195 non-null    object
#  8   Labour Force Participation Rate (Female)      195 non-null    object
# ...

# %%
pd_inequality_adjusted.head()
# Out:
#    IHDI Rank      Country  Human Development Index (HDI)  \
# 0        1.0       Norway                          0.944
# 1        2.0    Australia                          0.935
# 2        3.0  Switzerland                          0.930
# 3        4.0      Denmark                          0.923
# 4        5.0  Netherlands                          0.922
#
#   Inequality-adjusted HDI (IHDI) IHDI Loss Percent IHDI Rank Difference  \
# 0                          0.893               5.4                    0
# 1                          0.858               8.2                   -2
# 2                          0.861               7.4                    0
# 3                          0.856               7.3                   -1
# 4                          0.861               6.6                    3
#
#   Coefficient of Human Inequality Inequality in Life Expectancy  \
# 0                             5.3                           3.4
# ...

# %%
pd_inequality_adjusted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 16 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   IHDI Rank                                  188 non-null    float64
#  1   Country                                    195 non-null    object
#  2   Human Development Index (HDI)              195 non-null    float64
#  3   Inequality-adjusted HDI (IHDI)             195 non-null    object
#  4   IHDI Loss Percent                          195 non-null    object
#  5   IHDI Rank Difference                       188 non-null    object
#  6   Coefficient of Human Inequality            195 non-null    object
#  7   Inequality in Life Expectancy              195 non-null    object
#  8   Inequality-Adjusted Life Expectancy Index  195 non-null    object
#  9   Inequality in Education                    195 non-null    object
# ...

# %%
pd_nD_poverty.head()
# Out:
#        Country Year and Survey  Multidimensional Poverty Index (MPI, HDRO)  \
# 0  Afghanistan     2010/2011 M                                       0.293
# 1      Albania     2008/2009 D                                       0.005
# 2    Argentina          2005 N                                       0.015
# 3      Armenia          2010 D                                       0.002
# 4   Azerbaijan          2006 D                                       0.009
#
#    MPI HDRO Percent  Multidimensional Poverty Index (MPI, 2010)  \
# 0              58.8                                       0.353
# 1               1.2                                       0.005
# 2               3.7                                       0.011
# 3               0.6                                       0.001
# 4               2.4                                       0.021
#
#    MPI 2010 Percent Population in Multidimensional Poverty  \
# 0              66.2                                 17,116
# ...

# %%
pd_nD_poverty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 13 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country                                     101 non-null    object
#  1   Year and Survey                             101 non-null    object
#  2   Multidimensional Poverty Index (MPI, HDRO)  101 non-null    float64
#  3   MPI HDRO Percent                            101 non-null    float64
#  4   Multidimensional Poverty Index (MPI, 2010)  99 non-null     float64
#  5   MPI 2010 Percent                            99 non-null     float64
#  6   Population in Multidimensional Poverty      101 non-null    object
#  7   Intensity of Deprivation                    101 non-null    float64
#  8   Education Deprivation                       101 non-null    float64
# ...

# %%
pd_historical_index.head()
# Out:
#    HDI Rank      Country Human Development Index (1990)  \
# 0       1.0       Norway                          0.849
# 1       2.0    Australia                          0.865
# 2       3.0  Switzerland                          0.831
# 3       4.0      Denmark                          0.799
# 4       5.0  Netherlands                          0.829
#
#   Human Development Index (2000)  Human Development Index (2010)  \
# 0                          0.917                           0.940
# 1                          0.898                           0.927
# 2                          0.888                           0.924
# 3                          0.862                           0.908
# 4                          0.877                           0.909
#
#    Human Development Index (2011)  Human Development Index (2012)  \
# 0                           0.941                           0.942
# 1                           0.930                           0.932
# ...

# %%
pd_historical_index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   HDI Rank                        188 non-null    float64
#  1   Country                         195 non-null    object
#  2   Human Development Index (1990)  195 non-null    object
#  3   Human Development Index (2000)  195 non-null    object
#  4   Human Development Index (2010)  195 non-null    float64
#  5   Human Development Index (2011)  195 non-null    float64
#  6   Human Development Index (2012)  195 non-null    float64
#  7   Human Development Index (2013)  195 non-null    float64
#  8   Human Development Index (2014)  195 non-null    float64
# dtypes: float64(6), object(3)
# memory usage: 13.8+ KB

# %%
pd_historical_index.iloc[-10:-1,:]
# Out:
#      HDI Rank                          Country Human Development Index (1990)  \
# 185     186.0                          Eritrea                             ..
# 186     187.0         Central African Republic                          0.314
# 187     188.0                            Niger                          0.214
# 188       NaN                      Arab States                          0.553
# 189       NaN        East Asia and the Pacific                          0.516
# 190       NaN          Europe and Central Asia                          0.651
# 191       NaN  Latin America and the Caribbean                          0.625
# 192       NaN                       South Asia                          0.437
# 193       NaN               Sub-Saharan Africa                          0.400
#
#     Human Development Index (2000)  Human Development Index (2010)  \
# 185                             ..                           0.381
# ...

# %%
pd_historical_index.describe()
# Out:
#          HDI Rank  Human Development Index (2010)  \
# count  188.000000                      195.000000
# mean    94.313830                        0.678964
# std     54.431652                        0.155295
# min      1.000000                        0.326000
# 25%     47.750000                        0.550000
# 50%     94.000000                        0.711000
# 75%    141.250000                        0.793500
# max    188.000000                        0.940000
#
#        Human Development Index (2011)  Human Development Index (2012)  \
# count                      195.000000                      195.000000
# mean                         0.683159                        0.687123
# std                          0.154210                        0.153649
# min                          0.333000                        0.342000
# 25%                          0.559500                        0.567500
# 50%                          0.713000                        0.718000
# ...
